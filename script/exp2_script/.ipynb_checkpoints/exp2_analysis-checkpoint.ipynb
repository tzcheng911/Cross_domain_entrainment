# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load my data: can be accuracy or pss
# Add the headers: S short, M median, L long, E early, O ontime, Late, comp 1,2,3,4,5,6 
conditions = ['SE1','ME1','LE1','SO1','MO1','LO1','SL1','ML1','LL1',
                         'SE2','ME2','LE2','SO2','MO2','LO2','SL2','ML2','LL2',
                         'SE3','ME3','LE3','SO3','MO3','LO3','SL3','ML3','LL3',
                         'SE4','ME4','LE4','SO4','MO4','LO4','SL4','ML4','LL4',
                         'SE5','ME5','LE5','SO5','MO5','LO5','SL5','ML5','LL5',
                         'SE6','ME6','LE6','SO6','MO6','LO6','SL6','ML6','LL6']
acc = pd.read_csv('/Users/t.z.cheng/Google_Drive/Research/Delaydoesmatter/real_exp/exp2/data_analysis/acc.csv',
                  names=conditions)
acc.head(46)
# Out:
#         SE1      ME1      LE1      SO1      MO1      LO1      SL1      ML1  \
# 0   0.91667  0.75000  0.75000  0.83333  0.75000  0.83333  0.41667  0.75000
# 1   1.00000  1.00000  1.00000  1.00000  1.00000  1.00000  0.91667  0.91667
# 2   1.00000  1.00000  1.00000  0.91667  1.00000  0.91667  0.83333  1.00000
# 3   1.00000  1.00000  1.00000  0.66667  0.83333  0.75000  0.83333  0.75000
# 4   0.91667  0.75000  1.00000  0.66667  0.91667  1.00000  0.50000  1.00000
# 5   1.00000  0.83333  0.91667  0.83333  0.91667  0.83333  0.66667  0.91667
# 6   1.00000  1.00000  0.91667  0.50000  0.91667  0.91667  0.91667  0.75000
# 7   1.00000  1.00000  0.91667  0.83333  1.00000  1.00000  0.83333  0.91667
# 8   0.91667  0.91667  1.00000  0.91667  1.00000  0.91667  0.75000  1.00000
# 9   0.83333  0.66667  1.00000  0.83333  0.75000  1.00000  0.41667  0.75000
# 10  0.83333  0.83333  0.91667  0.41667  0.66667  1.00000  0.75000  0.50000
# 11  0.83333  0.83333  0.91667  0.83333  0.66667  0.50000  0.66667  0.75000
# 12  1.00000  1.00000  0.83333  0.83333  0.91667  0.91667  0.75000  0.83333
# 13  0.91667  0.91667  0.91667  0.91667  1.00000  1.00000  1.00000  1.00000
# 14  1.00000  0.91667  1.00000  0.91667  0.83333  0.83333  0.91667  0.91667
# 15  1.00000  1.00000  1.00000  1.00000  0.91667  0.91667  1.00000  0.83333
# 16  0.91667  0.83333  1.00000  0.66667  1.00000  0.91667  0.66667  1.00000
# 17  1.00000  1.00000  1.00000  0.66667  1.00000  0.91667  0.50000  0.91667
# 18  0.91667  0.91667  0.75000  0.50000  0.83333  1.00000  0.50000  0.91667
# 19  1.00000  1.00000  1.00000  0.50000  1.00000  0.91667  0.83333  1.00000
# 20  1.00000  0.75000  1.00000  0.91667  0.83333  0.91667  0.83333  0.75000
# 21  1.00000  1.00000  1.00000  0.75000  1.00000  0.91667  0.41667  1.00000
# 22  0.91667  0.83333  1.00000  0.83333  0.91667  0.83333  0.33333  0.91667
# 23  1.00000  1.00000  0.83333  0.58333  0.75000  0.66667  0.58333  0.91667
# 24  1.00000  1.00000  1.00000  1.00000  1.00000  1.00000  0.58333  1.00000
# 25  1.00000  1.00000  1.00000  1.00000  1.00000  1.00000  1.00000  1.00000
# 26  0.75000  1.00000  0.83333  0.50000  0.83333  0.83333  0.58333  0.83333
# 27  1.00000  0.91667  1.00000  1.00000  0.91667  1.00000  0.91667  0.91667
# 28  1.00000  1.00000  0.91667  0.91667  0.83333  1.00000  0.41667  0.91667
# 29  1.00000  1.00000  1.00000  1.00000  1.00000  1.00000  0.91667  1.00000
# 30  1.00000  1.00000  1.00000  1.00000  0.91667  1.00000  1.00000  0.91667
# 31  0.91667  0.91667  0.91667  1.00000  1.00000  1.00000  0.91667  0.91667
# 32  1.00000  1.00000  1.00000  0.91667  1.00000  1.00000  0.66667  1.00000
# 33  1.00000  1.00000  1.00000  1.00000  1.00000  1.00000  0.91667  0.91667
# 34  1.00000  0.83333  1.00000  0.75000  0.91667  1.00000  0.75000  1.00000
# 35  1.00000  1.00000  1.00000  0.91667  1.00000  1.00000  0.75000  1.00000
# 36  1.00000  1.00000  0.91667  0.66667  0.91667  0.66667  0.66667  0.91667
# 37  0.83333  1.00000  0.91667  0.91667  1.00000  0.91667  0.91667  0.91667
# 38  1.00000  1.00000  1.00000  0.91667  1.00000  1.00000  1.00000  1.00000
# 39  0.91667  0.75000  1.00000  0.75000  0.83333  0.91667  0.33333  0.83333
# 40  1.00000  1.00000  1.00000  0.91667  1.00000  1.00000  1.00000  1.00000
# 41  1.00000  1.00000  1.00000  1.00000  1.00000  1.00000  1.00000  1.00000
# 42  1.00000  1.00000  1.00000  1.00000  1.00000  1.00000  0.91667  1.00000
# 43  1.00000  1.00000  1.00000  0.91667  1.00000  1.00000  1.00000  1.00000
# 44  1.00000  1.00000  0.91667  0.75000  1.00000  1.00000  0.50000  1.00000
# 45  1.00000  0.91667  1.00000  1.00000  1.00000  1.00000  0.91667  0.91667
#
#         LL1      SE2  ...      LL5       SE6      ME6      LE6      SO6  \
# 0   0.66667  0.83333  ...  0.75000  0.416670  0.41667  0.75000  0.66667
# 1   1.00000  1.00000  ...  0.91667  0.666670  1.00000  1.00000  1.00000
# 2   1.00000  0.91667  ...  1.00000  0.000000  0.83333  0.83333  0.91667
# 3   1.00000  0.91667  ...  0.66667  0.416670  0.66667  0.91667  0.66667
# 4   1.00000  0.91667  ...  0.83333  0.333330  1.00000  1.00000  0.91667
# 5   0.91667  1.00000  ...  1.00000  0.833330  0.83333  1.00000  1.00000
# 6   0.83333  0.91667  ...  0.66667  0.250000  0.91667  0.83333  1.00000
# 7   1.00000  1.00000  ...  0.83333  0.166670  0.66667  0.91667  0.91667
# 8   1.00000  0.75000  ...  0.75000  0.416670  1.00000  1.00000  0.83333
# 9   1.00000  0.91667  ...  0.75000  0.166670  0.83333  0.75000  0.83333
# 10  1.00000  0.91667  ...  0.83333  0.250000  0.50000  0.75000  0.91667
# 11  0.75000  0.75000  ...  0.75000  0.750000  0.91667  1.00000  0.91667
# 12  0.91667  0.91667  ...  0.91667  0.250000  1.00000  0.91667  0.91667
# 13  0.91667  0.91667  ...  0.91667  0.666670  0.91667  0.91667  0.91667
# 14  1.00000  0.91667  ...  0.83333  0.250000  1.00000  1.00000  0.91667
# 15  1.00000  1.00000  ...  1.00000  0.500000  1.00000  1.00000  0.91667
# 16  1.00000  0.91667  ...  0.91667  0.666670  1.00000  0.66667  0.58333
# 17  0.83333  0.83333  ...  0.83333  0.416670  0.83333  1.00000  0.75000
# 18  0.66667  0.66667  ...  0.50000  0.500000  0.83333  0.58333  0.75000
# 19  0.91667  1.00000  ...  0.83333  0.500000  1.00000  0.83333  1.00000
# 20  0.91667  1.00000  ...  0.83333  0.250000  0.66667  0.58333  0.66667
# 21  1.00000  1.00000  ...  0.91667  0.250000  1.00000  1.00000  0.83333
# 22  1.00000  0.50000  ...  0.91667  0.833330  0.91667  0.83333  0.83333
# 23  0.91667  0.91667  ...  0.83333  0.250000  0.91667  0.91667  0.91667
# 24  1.00000  1.00000  ...  1.00000  0.416670  1.00000  1.00000  1.00000
# 25  0.91667  0.91667  ...  1.00000  0.750000  0.91667  0.91667  1.00000
# 26  0.75000  1.00000  ...  1.00000  0.500000  0.83333  1.00000  0.83333
# 27  0.83333  0.91667  ...  1.00000  0.750000  1.00000  0.91667  0.91667
# 28  0.91667  1.00000  ...  0.91667  0.333330  0.75000  0.75000  0.75000
# 29  1.00000  0.91667  ...  0.91667  0.583330  0.83333  0.91667  0.83333
# 30  1.00000  1.00000  ...  1.00000  0.583330  1.00000  1.00000  0.83333
# 31  1.00000  1.00000  ...  0.33333  0.416670  0.83333  0.91667  0.66667
# 32  1.00000  0.91667  ...  0.91667  0.500000  0.83333  1.00000  1.00000
# 33  0.91667  0.91667  ...  1.00000  0.416670  1.00000  1.00000  0.75000
# 34  0.91667  1.00000  ...  0.75000  0.333330  0.83333  0.75000  0.66667
# 35  1.00000  1.00000  ...  1.00000  0.416670  1.00000  1.00000  1.00000
# 36  0.83333  1.00000  ...  0.91667  0.250000  0.91667  0.83333  1.00000
# 37  0.91667  1.00000  ...  1.00000  0.750000  1.00000  1.00000  1.00000
# 38  1.00000  0.91667  ...  0.91667  0.666670  1.00000  1.00000  0.91667
# 39  1.00000  0.91667  ...  1.00000  0.166670  0.91667  1.00000  0.83333
# 40  1.00000  1.00000  ...  1.00000  0.166670  1.00000  1.00000  0.91667
# 41  1.00000  1.00000  ...  0.83333  0.500000  1.00000  1.00000  0.91667
# 42  0.91667  1.00000  ...  1.00000  0.750000  1.00000  0.91667  0.91667
# 43  1.00000  1.00000  ...  0.91667  0.416670  0.91667  1.00000  0.91667
# 44  1.00000  1.00000  ...  0.91667  0.083333  0.83333  1.00000  0.83333
# 45  0.91667  1.00000  ...  0.91667  0.166670  0.83333  1.00000  0.75000
#
#         MO6      LO6      SL6      ML6      LL6
# 0   0.58333  0.58333  1.00000  0.91667  0.58333
# 1   0.91667  1.00000  1.00000  1.00000  1.00000
# 2   0.91667  1.00000  1.00000  0.91667  0.91667
# 3   0.75000  0.75000  1.00000  0.75000  0.75000
# 4   1.00000  1.00000  1.00000  1.00000  1.00000
# 5   0.91667  0.91667  1.00000  0.91667  1.00000
# 6   0.91667  1.00000  0.91667  1.00000  0.75000
# 7   0.91667  0.83333  1.00000  0.91667  0.66667
# 8   0.91667  0.75000  0.91667  0.83333  0.83333
# 9   1.00000  0.75000  0.83333  0.75000  0.75000
# 10  0.91667  0.83333  0.91667  0.83333  1.00000
# 11  1.00000  1.00000  0.75000  0.91667  0.91667
# 12  0.83333  1.00000  1.00000  1.00000  0.91667
# 13  1.00000  1.00000  0.91667  1.00000  1.00000
# 14  1.00000  1.00000  1.00000  1.00000  1.00000
# 15  0.91667  1.00000  1.00000  1.00000  1.00000
# 16  0.83333  1.00000  0.91667  0.83333  0.66667
# 17  0.83333  1.00000  1.00000  1.00000  0.91667
# 18  1.00000  0.91667  0.91667  0.75000  0.83333
# 19  1.00000  1.00000  1.00000  1.00000  1.00000
# 20  0.75000  0.66667  0.91667  0.41667  0.75000
# 21  0.91667  1.00000  0.91667  0.91667  0.91667
# 22  0.83333  0.91667  1.00000  0.83333  0.83333
# 23  0.58333  0.83333  0.91667  1.00000  0.66667
# 24  1.00000  1.00000  1.00000  1.00000  1.00000
# 25  0.91667  1.00000  0.91667  1.00000  1.00000
# 26  0.83333  0.91667  0.91667  0.83333  0.91667
# 27  1.00000  1.00000  1.00000  1.00000  1.00000
# 28  0.75000  0.83333  0.83333  0.75000  0.91667
# 29  1.00000  1.00000  0.91667  0.83333  1.00000
# 30  1.00000  0.91667  0.83333  1.00000  1.00000
# 31  0.91667  0.91667  0.75000  0.91667  0.83333
# 32  1.00000  1.00000  0.91667  1.00000  0.91667
# 33  0.91667  1.00000  1.00000  1.00000  1.00000
# 34  0.91667  0.83333  0.83333  0.75000  1.00000
# 35  1.00000  1.00000  1.00000  1.00000  1.00000
# 36  1.00000  0.91667  1.00000  1.00000  0.91667
# 37  1.00000  1.00000  1.00000  1.00000  1.00000
# 38  1.00000  1.00000  1.00000  1.00000  0.91667
# 39  1.00000  1.00000  0.83333  0.91667  0.91667
# 40  1.00000  1.00000  1.00000  1.00000  1.00000
# 41  1.00000  1.00000  0.91667  1.00000  0.83333
# 42  1.00000  1.00000  1.00000  1.00000  1.00000
# 43  0.83333  1.00000  1.00000  0.83333  1.00000
# 44  0.91667  0.91667  1.00000  0.91667  1.00000
# 45  0.83333  0.83333  1.00000  0.91667  0.91667
#
# [46 rows x 54 columns]

# %%
acc = acc.drop([2,6,10,13,17,23],axis = 0)
mean = np.mean(acc)
stderr = np.std(acc)/(len(acc)**0.5)

# %%
fig, ax = plt.subplots()
delay = ('Short','Median','Long')
y_pos = np.arange(len(conditions))
plt.bar(y_pos,mean, width=0.5, yerr=stderr, color='orange',align='center')
plt.xticks(y_pos, conditions)
plt.ylabel('Accuracy')
plt.yticks(np.arange(0, 1.1, 0.1))
plt.title('Accuracy against Delay Length')
# Out:
# Text(0.5, 1.0, 'Accuracy against Delay Length')

# %%
## Accuracy check (stop rule = 0.6): easiest comparison duration in short, median and long delay
## Outliers based on the accuracy < 0.6: 2, 14, 18, 22, 43 2020/2/25 Zoe
## Outliers because other reasons (i.e. can't finish the task, can't pass the practice): 3, 7, 11, 24 2020/2/25 Zoe
easy_trials_short = acc[['SE1','ME1','LE1','SO1','MO1','LO1','SL1','ML1','LL1','SE6','ME6','LE6','SO6','MO6','LO6','SL6','ML6','LL6']]
easy_trials_long = acc[['SE1','ME1','LE1','SO1','MO1','LO1','SL1','ML1','LL1','SE6','ME6','LE6','SO6','MO6','LO6','SL6','ML6','LL6']]

mean_easy_trials = np.mean(easy_trials,axis = 1)
mean_easy_trials.head(45)
# Out:
# 0     0.699074
# 1     0.967593
# 3     0.805556
# 4     0.888889
# 5     0.902778
# 7     0.861112
# 8     0.884260
# 9     0.773148
# 11    0.828704
# 12    0.879630
# 14    0.916667
# 15    0.944445
# 16    0.842593
# 18    0.782408
# 19    0.916667
# 20    0.754631
# 21    0.879631
# 22    0.856481
# 24    0.944444
# 25    0.962964
# 26    0.805554
# 27    0.949075
# 28    0.810186
# 29    0.935185
# 30    0.944444
# 31    0.875002
# 32    0.930556
# 33    0.935186
# 34    0.837963
# 35    0.949074
# 36    0.856483
# 37    0.949075
# 38    0.967593
# 39    0.828704
# 40    0.944445
# 41    0.953704
# 42    0.967593
# 43    0.935186
# 44    0.870371
# 45    0.884260
# 46    0.810186
# 47    0.953704
# dtype: float64

# %%
## Onset time: early, ontime, late
early_trials = acc[['SE1','ME1','LE1','SE2','ME2','LE2','SE3','ME3','LE3','SE4','ME4','LE4','SE5','ME5','LE5','SE6','ME6','LE6']]
ontime_trials = acc[['SO1','MO1','LO1','SO2','MO2','LO2','SO3','MO3','LO3','SO4','MO4','LO4','SO5','MO5','LO5','SO6','MO6','LO6']]
late_trials = acc[['SL1','ML1','LL1','SL2','ML2','LL2','SL3','ML3','LL3','SL4','ML4','LL4','SL5','ML5','LL5','SL6','ML6','LE6']]
onset_mean = [np.mean(np.mean(early_trials)),np.mean(np.mean(ontime_trials)),np.mean(np.mean(late_trials))]
n = (len(acc)**0.5)
onset_stderr = [np.std(np.mean(early_trials,axis=1))/n,np.std(np.mean(ontime_trials,axis=1))/n,np.std(np.mean(late_trials,axis=1))/n]

fig, ax = plt.subplots()
onset = ('Early', 'Ontime', 'Late')
y_pos = np.arange(3)
plt.bar(y_pos,onset_mean, width=0.5, yerr=onset_stderr, color='orange',align='center')
plt.xticks(y_pos, onset)
plt.ylabel('Accuracy')
plt.yticks(np.arange(0, 1.1, 0.1))
plt.title('Accuracy against Delay Length')

# %%
## Delay length: short, median, long
short_trials = acc[['SE1','SE2','SE3','SE4','SE5','SE6','SO1','SO2','SO3','SO4','SO5','SO6','SL1','SL2','SL3','SL4','SL5','SL6']]
median_trials = acc[['ME1','ME2','ME3','ME4','ME5','ME6','MO1','MO2','MO3','MO4','MO5','MO6','ML1','ML2','ML3','ML4','ML5','ML6']]
long_trials = acc[['LE1','LE2','LE3','LE4','LE5','LE6','LO1','LO2','LO3','LO4','LO5','LO6','LL1','LL2','LL3','LL4','LL5','LL6']]
delay_mean = [np.mean(np.mean(short_trials)),np.mean(np.mean(median_trials)),np.mean(np.mean(long_trials))]
n = (len(acc)**0.5)
delay_stderr = [np.std(np.mean(short_trials,axis=1))/n,np.std(np.mean(median_trials,axis=1))/n,np.std(np.mean(long_trials,axis=1))/n]


fig, ax = plt.subplots()
delay = ('Short','Median','Long')
y_pos = np.arange(3)
plt.bar(y_pos,delay_mean, width=0.5, yerr=delay_stderr, color='orange',align='center')
plt.xticks(y_pos, delay)
plt.ylabel('Accuracy')
plt.yticks(np.arange(0, 1.1, 0.1))
plt.title('Accuracy against Delay Length')

# %%
## Delay length: short, median, long x Onset time: early, ontime, late
early_short = acc[['SE1','SE2','SE3','SE4','SE5','SE6']]
early_median = acc[['ME1','ME2','ME3','ME4','ME5','ME6']]
early_long = acc[['LE1','LE2','LE3','LE4','LE5','LE6']]

ontime_short = acc[['SO1','SO2','SO3','SO4','SO5','SO6']]
ontime_median = acc[['MO1','MO2','MO3','MO4','MO5','MO6']]
ontime_long = acc[['LO1','LO2','LO3','LO4','LO5','LO6']]

late_short = acc[['SL1','SL2','SL3','SL4','SL5','SL6']]
late_median = acc[['ML1','ML2','ML3','ML4','ML5','ML6']]
late_long = acc[['LL1','LL2','LL3','LL4','LL5','LL6']]

means_early_delay = [np.mean(np.mean(early_short)),np.mean(np.mean(early_median)),np.mean(np.mean(early_long))]
means_ontime_delay = [np.mean(np.mean(ontime_short)),np.mean(np.mean(ontime_median)),np.mean(np.mean(ontime_long))]
means_late_delay = [np.mean(np.mean(late_short)),np.mean(np.mean(late_median)),np.mean(np.mean(late_long))]

n_groups = 3
fig, ax = plt.subplots()
y_pos = np.arange(n_groups)
bar_width = 0.15
opacity = 0.8

rects1 = plt.bar(y_pos-bar_width,means_early_delay, bar_width, yerr=delay_stderr, color='orange',label = 'Early')
rects2 = plt.bar(y_pos,means_ontime_delay, bar_width, yerr=onset_stderr, color='red',label = 'Ontime')
rects3 = plt.bar(y_pos+bar_width,means_late_delay, bar_width, yerr=onset_stderr, color='pink',label = 'Late')

plt.xticks(y_pos, delay)
plt.ylabel('Accuracy')
plt.yticks(np.arange(0, 1.1, 0.1))
plt.title('Accuracy against Delay Length')
plt.legend()

# %%
len(acc)
