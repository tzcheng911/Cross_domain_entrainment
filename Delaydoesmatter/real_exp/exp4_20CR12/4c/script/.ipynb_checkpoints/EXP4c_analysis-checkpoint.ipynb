# %%
import csv
import numpy as np
import pandas as pd
from collections import defaultdict
import string
import seaborn as sns
from scipy import stats
from sklearn import linear_model
from sklearn import metrics # confusion matrix, MSE etc.

# %%
path_to_data = "/Users/t.z.cheng/Google_Drive/Research/Delaydoesmatter/real_exp/exp4_20CR12/4c/results/session-62159fb8dfe54372fbc126e5-data.csv"

# %%
## Read the data
df = pd.read_csv(path_to_data)
df.groupby('stimuli_presented').describe()
# Out:
#                                        network_error_repeat                 \
#                                                       count mean  std  min
# stimuli_presented
# Age                                                     3.0  0.0  0.0  0.0
# AnyOtherLang                                            3.0  0.0  0.0  0.0
# DomLang                                                 3.0  0.0  0.0  0.0
# DomLangQs                                               3.0  0.0  0.0  0.0
# Gender                                                  3.0  0.0  0.0  0.0
# LangPrefs                                               3.0  0.0  0.0  0.0
# NonDomLang                                              3.0  0.0  0.0  0.0
# NonDomLangQs                                            3.0  0.0  0.0  0.0
# cat_meowing                                            39.0  0.0  0.0  0.0
# debrief1                                                3.0  0.0  0.0  0.0
# debrief2                                                3.0  0.0  0.0  0.0
# debrief3                                                3.0  0.0  0.0  0.0
# logistic_headphone1                                     3.0  0.0  0.0  0.0
# logistic_headphone2                                     3.0  0.0  0.0  0.0
# logistics_noise                                         3.0  0.0  0.0  0.0
# long_tone_8                                            96.0  0.0  0.0  0.0
# musicbackground1                                        3.0  0.0  0.0  0.0
# musicbackground2                                        3.0  0.0  0.0  0.0
# musicbackground3                                        3.0  0.0  0.0  0.0
# short_tone_1                                           96.0  0.0  0.0  0.0
# single_300ms_early_delay_2_tone_Lab_1                  36.0  0.0  0.0  0.0
# single_300ms_early_delay_2_tone_Lab_2                  36.0  0.0  0.0  0.0
# single_300ms_early_delay_2_tone_Lab_3                  36.0  0.0  0.0  0.0
# single_300ms_early_delay_2_tone_Lab_4                  36.0  0.0  0.0  0.0
# single_300ms_early_delay_2_tone_Lab_5                  36.0  0.0  0.0  0.0
# single_300ms_early_delay_2_tone_Lab_6                  36.0  0.0  0.0  0.0
# single_300ms_early_delay_2_tone_Lab_7                  36.0  0.0  0.0  0.0
# single_300ms_early_delay_2_tone_Lab_8                  36.0  0.0  0.0  0.0
# single_300ms_late_delay_2_tone_Lab_1                   36.0  0.0  0.0  0.0
# single_300ms_late_delay_2_tone_Lab_2                   36.0  0.0  0.0  0.0
# single_300ms_late_delay_2_tone_Lab_3                   36.0  0.0  0.0  0.0
# single_300ms_late_delay_2_tone_Lab_4                   36.0  0.0  0.0  0.0
# single_300ms_late_delay_2_tone_Lab_5                   36.0  0.0  0.0  0.0
# single_300ms_late_delay_2_tone_Lab_6                   36.0  0.0  0.0  0.0
# single_300ms_late_delay_2_tone_Lab_7                   36.0  0.0  0.0  0.0
# single_300ms_late_delay_2_tone_Lab_8                   36.0  0.0  0.0  0.0
# single_300ms_ontime_delay_2_tone_Lab_1                 78.0  0.0  0.0  0.0
# single_300ms_ontime_delay_2_tone_Lab_2                 36.0  0.0  0.0  0.0
# single_300ms_ontime_delay_2_tone_Lab_3                 36.0  0.0  0.0  0.0
# single_300ms_ontime_delay_2_tone_Lab_4                 36.0  0.0  0.0  0.0
# single_300ms_ontime_delay_2_tone_Lab_5                 36.0  0.0  0.0  0.0
# single_300ms_ontime_delay_2_tone_Lab_6                 36.0  0.0  0.0  0.0
# single_300ms_ontime_delay_2_tone_Lab_7                 36.0  0.0  0.0  0.0
# single_300ms_ontime_delay_2_tone_Lab_8                 78.0  0.0  0.0  0.0
# songbird                                               39.0  0.0  0.0  0.0
#
#                                                             \
#                                         25%  50%  75%  max
# stimuli_presented
# Age                                     0.0  0.0  0.0  0.0
# AnyOtherLang                            0.0  0.0  0.0  0.0
# DomLang                                 0.0  0.0  0.0  0.0
# DomLangQs                               0.0  0.0  0.0  0.0
# Gender                                  0.0  0.0  0.0  0.0
# LangPrefs                               0.0  0.0  0.0  0.0
# NonDomLang                              0.0  0.0  0.0  0.0
# NonDomLangQs                            0.0  0.0  0.0  0.0
# cat_meowing                             0.0  0.0  0.0  0.0
# debrief1                                0.0  0.0  0.0  0.0
# debrief2                                0.0  0.0  0.0  0.0
# debrief3                                0.0  0.0  0.0  0.0
# logistic_headphone1                     0.0  0.0  0.0  0.0
# logistic_headphone2                     0.0  0.0  0.0  0.0
# logistics_noise                         0.0  0.0  0.0  0.0
# long_tone_8                             0.0  0.0  0.0  0.0
# musicbackground1                        0.0  0.0  0.0  0.0
# musicbackground2                        0.0  0.0  0.0  0.0
# musicbackground3                        0.0  0.0  0.0  0.0
# short_tone_1                            0.0  0.0  0.0  0.0
# single_300ms_early_delay_2_tone_Lab_1   0.0  0.0  0.0  0.0
# single_300ms_early_delay_2_tone_Lab_2   0.0  0.0  0.0  0.0
# single_300ms_early_delay_2_tone_Lab_3   0.0  0.0  0.0  0.0
# single_300ms_early_delay_2_tone_Lab_4   0.0  0.0  0.0  0.0
# single_300ms_early_delay_2_tone_Lab
# single_300ms_early_delay_2_tone_Lab_3   ...        4019.00     7703.0
# single_300ms_early_delay_2_tone_Lab_4   ...        3623.50     4669.0
# single_300ms_early_delay_2_tone_Lab_5   ...        3902.50     5468.0
# single_300ms_early_delay_2_tone_Lab_6   ...        3687.75    11307.0
# single_300ms_early_delay_2_tone_Lab_7   ...        3857.25    13827.0
# single_300ms_early_delay_2_tone_Lab_8   ...        4032.50    10372.0
# single_300ms_late_delay_2_tone_Lab_1    ...        3847.25     5506.0
# single_300ms_late_delay_2_tone_Lab_2    ...        3844.50    18966.0
# single_300ms_late_delay_2_tone_Lab_3    ...        3916.25     6888.0
# single_300ms_late_delay_2_tone_Lab_4    ...        3969.25    52874.0
# single_300ms_late_delay_2_tone_Lab_5    ...        3745.25     6687.0
# single_300ms_late_delay_2_tone_Lab_6    ...        3921.00    23525.0
# single_300ms_late_delay_2_tone_Lab_7    ...        3871.25     7627.0
# single_300ms_late_delay_2_tone_Lab_8    ...        3799.00     4642.0
# single_300ms_ontime_delay_2_tone_Lab_1  ...        6265.50     8812.0
# single_300ms_ontime_delay_2_tone_Lab_2  ...        3971.25     4849.0
# single_300ms_ontime_delay_2_tone_Lab_3  ...        4061.75     6956.0
# single_300ms_ontime_delay_2_tone_Lab_4  ...        3807.25     4405.0
# single_300ms_ontime_delay_2_tone_Lab_5  ...        3689.75     4845.0
# single_300ms_ontime_delay_2_tone_Lab_6  ...        3772.75     4184.0
# single_300ms_ontime_delay_2_tone_Lab_7  ...        3602.00     5065.0
# single_300ms_ontime_delay_2_tone_Lab_8  ...        6396.75    19816.0
# songbird                                ...        3970.50     7350.0
#
#                                        trial_num                          \
#                                            count        mean         std
# stimuli_presented
# Age                                          3.0  420.000000    0.000000
# AnyOtherLang                                 3.0  414.000000    0.000000
# DomLang                                      3.0  410.000000    0.000000
# DomLangQs                                    3.0  411.000000    0.000000
# Gender                                       3.0  419.000000    0.000000
# LangPrefs                                    3.0  415.000000    0.000000
# NonDomLang                                   3.0  412.000000    0.000000
# NonDomLangQs                                 3.0  413.000000    0.000000
# cat_meowing                                 39.0  179.000000   45.486840
# debrief1                                     3.0  421.000000    0.000000
# debrief2                                     3.0  422.000000    0.000000
# debrief3                                     3.0  423.000000    0.000000
# logistic_headphone1                          3.0    2.000000    0.000000
# logistic_headphone2                          3.0    3.000000    0.000000
# logistics_noise                              3.0    1.000000    0.000000
# long_tone_8                                 96.0   35.541667   18.688537
# musicbackground1                             3.0  416.000000    0.000000
# musicbackground2                             3.0  417.000000    0.000000
# musicbackground3                             3.0  418.000000    0.000000
# short_tone_1                                96.0   35.458333   18.450455
# single_300ms_early_delay_2_tone_Lab_1       36.0  251.861111   91.394952
# single_300ms_early_delay_2_tone_Lab_2       36.0  253.722222   90.721115
# single_300ms_early_delay_2_tone_Lab_3       36.0  255.500000   92.011335
# single_300ms_early_delay_2_tone_Lab_4       36.0  251.444444   92.508361
# single_300ms_early_delay_2_tone_Lab_5       36.0  251.972222   91.573385
# single_300ms_early_delay_2_tone_Lab_4    98.0  185.75  252.0  318.50  401.0
# single_300ms_early_delay_2_tone_Lab_5   103.0  174.75  254.0  330.50  402.0
# single_300ms_early_delay_2_tone_Lab_6   101.0  174.50  249.5  328.00  406.0
# single_300ms_early_delay_2_tone_Lab_7   101.0  173.50  258.5  322.75  387.0
# single_300ms_early_delay_2_tone_Lab_8    99.0  170.50  259.0  328.00  398.0
# single_300ms_late_delay_2_tone_Lab_1     96.0  175.75  248.5  320.50  409.0
# single_300ms_late_delay_2_tone_Lab_2     96.0  173.50  248.5  318.25  406.0
# single_300ms_late_delay_2_tone_Lab_3     99.0  182.50  258.5  326.00  406.0
# single_300ms_late_delay_2_tone_Lab_4    104.0  179.00  257.0  332.25  407.0
# single_300ms_late_delay_2_tone_Lab_5    100.0  177.75  252.0  330.75  395.0
# single_300ms_late_delay_2_tone_Lab_6    104.0  173.75  251.0  328.25  389.0
# single_300ms_late_delay_2_tone_Lab_7    106.0  174.75  252.5  327.00  407.0
# single_300ms_late_delay_2_tone_Lab_8    110.0  174.00  253.0  321.25  404.0
# single_300ms_ontime_delay_2_tone_Lab_1   68.0   80.25   93.5  247.75  409.0
# single_300ms_ontime_delay_2_tone_Lab_2   96.0  181.00  251.5  324.75  407.0
# single_300ms_ontime_delay_2_tone_Lab_3   98.0  180.25  246.5  332.00  409.0
# single_300ms_ontime_delay_2_tone_Lab_4   97.0  174.50  248.0  328.25  403.0
# single_300ms_ontime_delay_2_tone_Lab_5  102.0  175.75  252.5  324.25  405.0
# single_300ms_ontime_delay_2_tone_Lab_6  100.0  181.25  246.5  326.00  397.0
# single_300ms_ontime_delay_2_tone_Lab_7  103.0  174.25  252.0  325.50  404.0
# single_300ms_ontime_delay_2_tone_Lab_8   68.0   81.00   93.5  235.50  392.0
# songbird                                264.0  300.00  336.0  372.00  408.0
#
# [45 rows x 40 columns]

# %%
## Tasks & Conditions: Clean up task and subject ID (first five characters)
df['task'] = df['trial_template'].apply(lambda x: x.split("_")[0])
df['sub_id'] = df['participant_id'].apply(lambda x: x.split()[0][0:5])

conds = ['single_300ms_early_delay_2_tone_Lab_1','single_300ms_delay_2_52','single_300ms_delay_2_53','single_300ms_delay_2_54','single_300ms_delay_2_55','single_300ms_delay_2_56',
        'single_300ms_delay_2_81','single_300ms_delay_2_82','single_300ms_delay_2_83','single_300ms_delay_2_84','single_300ms_delay_2_85','single_300ms_delay_2_86',
        'single_300ms_delay_2_91','single_300ms_delay_2_92','single_300ms_delay_2_93','single_300ms_delay_2_94','single_300ms_delay_2_95','single_300ms_delay_2_96']
subID = df['participant_id'].unique()

# %%
tasks = ['PretestTrials_s','PretestTrials_l','PretestTrials_s_reversekey','PretestTrials_l_reversekey']
conds = ['short_tone_1','long_tone_8']
df_clean = df[(df['trial_template'].isin(tasks))]

# %%
## Parameters
threshold = .55

# %%
df_clean = df[(df['stimuli_presented'].isin(conds)) & (df['trial_template'].isin(tasks))]

# %%
onset = []
length = []
df_clean = df_clean.set_index(pd.Index(np.arange(0,len(df_clean)))) # change the index for the for loop

for i in np.arange(0,len(df_clean)):
    stimuli_presented = df_clean['stimuli_presented'][i].split('_')
    condition = stimuli_presented[-1]
    condition = list(condition)
    onset.append(condition[0])
    length.append(condition[1])

# %%
df_clean['Onset'] = onset
df_clean['Length'] = length

# %%
## Number of subjects, trials & conditions for each subjects
n_subj = len(df_clean['participant_id'].unique())
n_trial = len(df_clean['trial_num'].unique())
n_conds = len(df_clean['stimuli_presented'].unique())
print('Participant_number:', n_subj,'Trial number:', n_trial,'Condition number:', n_conds, sep='\n')

# %%
resp_short = []
resp_short = [True if d == 'Shorter' else False for d in df_clean['response_value']]
df_clean['resp_short'] = resp_short
PPS = []
PPS_cond = []
for sub in subID:
    tmpdf = df_clean[df_clean['participant_id'] == sub]
    for cond in conds:
        tmpPPS = np.mean(tmpdf[tmpdf['stimuli_presented'] == cond]['resp_short'])
        PPS_cond.append(tmpPPS)
    PPS.append(PPS_cond)
    PPS_cond = []

# %%
np.mean(PPS,axis = 0)

# %% [markdown]
# ### Accuracy

# %%
Accuracy = []
Acc_cond = []
Easiest = []
Easiest_idx = [conds.index('single_300ms_delay_2_81'),conds.index('single_300ms_delay_2_86')]
for sub in subID:
    tmpdf = df_clean[df_clean['participant_id'] == sub]
    for cond in conds:
        tmpAcc = np.mean(tmpdf[tmpdf['stimuli_presented'] == cond]['response_correct'])
        Acc_cond.append(tmpAcc)
    Easiest.append((Acc_cond[Easiest_idx[0]] + Acc_cond[Easiest_idx[-1]])/len(Easiest_idx)) # average accuracy of 81 and 86 
    Accuracy.append(Acc_cond)
    Acc_cond = []

# %%
## Outliers based on the accuracy of the easiest trials 
Acc_easiest = pd.Series(Easiest, index=df_clean['participant_id'].unique())
print(Acc_easiest.describe())
t = Acc_easiest[Acc_easiest >= threshold]
print("Subjects who have >=",threshold, "accuracy for the easiest trials:",len(t))

# %%
df_Accuracy = pd.DataFrame(data = Accuracy, index = subID, columns = conds)
Acc_final_sample = df_Accuracy[Acc_easiest >= threshold]
Acc_final_sample.head()
print('Final sample size:', len(Acc_final_sample))
# Acc_final_sample.describe()

# %%
outliers = Acc_easiest < threshold
outliers = outliers[outliers == True]
df_clean_nooutlier = df_clean[~df_clean['participant_id'].isin(outliers.index)]
len(df_clean_nooutlier)/216

# %%
## Save the dataset to csv
df_clean_nooutlier.to_csv(path_or_buf = '/Users/t.z.cheng/Google_Drive/Research/Delaydoesmatter/real_exp/exp4_20CR12/results/20CR12_clean_n53.csv', index=True)

# %%
## Early, ontime, late
early = [conds.index('single_300ms_delay_2_51'),conds.index('single_300ms_delay_2_52'),conds.index('single_300ms_delay_2_53'),conds.index('single_300ms_delay_2_54'),conds.index('single_300ms_delay_2_55'),conds.index('single_300ms_delay_2_56')]
ontime = [conds.index('single_300ms_delay_2_81'),conds.index('single_300ms_delay_2_82'),conds.index('single_300ms_delay_2_83'),conds.index('single_300ms_delay_2_84'),conds.index('single_300ms_delay_2_85'),conds.index('single_300ms_delay_2_86')]
late = [conds.index('single_300ms_delay_2_91'),conds.index('single_300ms_delay_2_92'),conds.index('single_300ms_delay_2_93'),conds.index('single_300ms_delay_2_94'),conds.index('single_300ms_delay_2_95'),conds.index('single_300ms_delay_2_96')]
Acc_early = Acc_final_sample.iloc[:, early].mean(axis = 1)
Acc_ontime = Acc_final_sample.iloc[:, ontime].mean(axis = 1)
Acc_late = Acc_final_sample.iloc[:, late].mean(axis = 1)
print("Accuracy")
print("Early:", np.mean(Acc_early))
print("Ontime:", np.mean(Acc_ontime))
print("Late:",np.mean(Acc_late))

# %%
## Visualization: bar plot
ACC_plot = pd.DataFrame({'Conditions': conds, 'acc': np.mean(Acc_final_sample, axis = 0)})
ax = ACC_plot.plot.bar(rot = 0)

# %% [markdown]
# ### Proportion short

# %%
resp_short = []
resp_short = [True if d == 'Shorter' else False for d in df_clean['response_value']]

# %%
df_clean['resp_short'] = resp_short

# %%
PPS = []
PPS_cond = []
for sub in subID:
    tmpdf = df_clean[df_clean['participant_id'] == sub]
    for cond in conds:
        tmpPPS = np.mean(tmpdf[tmpdf['stimuli_presented'] == cond]['resp_short'])
        PPS_cond.append(tmpPPS)
    PPS.append(PPS_cond)
    PPS_cond = []

# %%
df_PPS = pd.DataFrame(data = PPS, index = subID, columns = conds)

# %%
PPS_final_sample = df_PPS[Acc_easiest >= threshold]
PPS_final_sample.head()
PPS_final_sample.describe()

# %%
## Early, ontime, late
early = [conds.index('single_300ms_delay_2_51'),conds.index('single_300ms_delay_2_52'),conds.index('single_300ms_delay_2_53'),conds.index('single_300ms_delay_2_54'),conds.index('single_300ms_delay_2_55'),conds.index('single_300ms_delay_2_56')]
ontime = [conds.index('single_300ms_delay_2_81'),conds.index('single_300ms_delay_2_82'),conds.index('single_300ms_delay_2_83'),conds.index('single_300ms_delay_2_84'),conds.index('single_300ms_delay_2_85'),conds.index('single_300ms_delay_2_86')]
late = [conds.index('single_300ms_delay_2_91'),conds.index('single_300ms_delay_2_92'),conds.index('single_300ms_delay_2_93'),conds.index('single_300ms_delay_2_94'),conds.index('single_300ms_delay_2_95'),conds.index('single_300ms_delay_2_96')]
PPS_early = PPS_final_sample.iloc[:, early].mean(axis = 1)
PPS_ontime = PPS_final_sample.iloc[:, ontime].mean(axis = 1)
PPS_late = PPS_final_sample.iloc[:, late].mean(axis = 1)
print("Proportion short")
print("Early:", np.mean(PPS_early))
print("Ontime:", np.mean(PPS_ontime))
print("Late:",np.mean(PPS_late))

# %%
## Visualization: bar plot
PPS_plot = pd.DataFrame({'Conditions': conds, 'PSS': np.mean(PPS_final_sample, axis = 0)})
ax = PPS_plot.plot.bar(rot = 0)

# %% [markdown]
# ### Statistic tests

# %%
print(stats.ttest_rel(PPS_early, PPS_late))
print(stats.ttest_rel(PPS_early, PPS_ontime))
print(stats.ttest_rel(PPS_late, PPS_ontime))
