# %%
import csv
import numpy as np
import pandas as pd
from collections import defaultdict
import string
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from sklearn import linear_model
from sklearn import metrics # confusion matrix, MSE etc.

# %%
path_to_data = "/Users/t.z.cheng/Google_Drive/Research/cross_domain_entrainment/exp8/results/session-635300ef7f3ee915ba688e53-data.csv"

# %%
## Read the data
df = pd.read_csv(path_to_data)
# df.groupby('stimuli_presented').describe()

# %%
## Tasks & Conditions: Clean up task and subject ID (first five characters)
# df['task'] = df['trial_template'].apply(lambda x: x.split("_")[0])
df['sub_id'] = df['participant_id'].apply(lambda x: x.split()[0][0:5])
## for exp8abc
df['exp'] = df['group_id'].apply(lambda x: x.split("_")[0])
df_exp8c = df[(df['exp'] == 'EXP8c')].reset_index(drop = True)
df = df_exp8c

# %%
## Add the accuracy and PPS column to the dataset: transform True and Shorter to 1, False and longer to 0
Correct = [] # only applied for the prescreen
Shorter = []
for i in np.arange(0,len(df)):
    if df['response_correct'][i] == True:
        Correct.append(1)
    else: 
        Correct.append(0)
    if ((df['response_value'][i] == "Lap") or (df['response_value'][i] == "Shorter")): 
        Shorter.append(1)
    else: 
        Shorter.append(0)
df['Correct'] = Correct
df['Shorter'] = Shorter

# %%
df[100:150]
# Out:
#     branch_failpass                   expt_id  group_id  network_error_repeat  \
# 100            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 101            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 102            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 103            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 104            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 105            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 106            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 107            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 108            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 109            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 110            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 111            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 112            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 113            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 114            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 115            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 116            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 117            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 118            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 119            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 120            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 121            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 122            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 123            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 124            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 125            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 126            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 127            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 128            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 129            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 130            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 131            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 132            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 133            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 134            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 135            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 136            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 137            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 138            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 139            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 140            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 141            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 142            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 143            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 144            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 145            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 146            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 147            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 148            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
# 149            pass  6345b7f49677d36bd07c5a10  EXP8c_FJ                     0
#
#                                         participant_id  \
# 100  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 101  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 102  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 103  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 104  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 105  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 106  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 107  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 108  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 109  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 110  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 111  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 112  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 113  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 114  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 115  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 116  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 117  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 118  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 119  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 120  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 121  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 122  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 123  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 124  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 125  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 126  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 127  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 128  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 129  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 130  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 131  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 132  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 133  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 134  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 135  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 136  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 137  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 138  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 139  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 140  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 141  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 142  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 143  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 144  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 145  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 146  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 147  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 148  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
# 149  cbea07ee944e05e13c351ed430b8d6dc4ef2c8fbc020ee...
#
#      participation_duration response_correct response_mode  response_name  \
# 100              1916.56069            False      keypress  EXP8c_testRsp
# 101              1916.56069            False      keypress  EXP8c_testRsp
# 102              1916.56069            False      keypress  EXP8c_testRsp
# 103              1916.56069            False      keypress  EXP8c_testRsp
# 104              1916.56069            False      keypress  EXP8c_testRsp
# 105              1916.56069            False      keypress  EXP8c_testRsp
# 106              1916.56069             True      keypress   cat_catchRsp
# 107              1916.56069            False      keypress  EXP8c_testRsp
# 108              1916.56069            False      keypress  EXP8c_testRsp
# 109              1916.56069            False      keypress  EXP8c_testRsp
# 110              1916.56069            False      keypress  EXP8c_testRsp
# 111              1916.56069            False      keypress  EXP8c_testRsp
# 112              1916.56069            False      keypress  EXP8c_testRsp
# 113              1916.56069            False      keypress  EXP8c_testRsp
# 114              1916.56069            False      keypress  EXP8c_testRsp
# 115              1916.56069            False      keypress  EXP8c_testRsp
# 116              1916.56069            False      keypress  EXP8c_testRsp
# 117              1916.56069            False      keypress  EXP8c_testRsp
# 118              1916.56069             True      keypress  bird_catchRsp
# 119              1916.56069            False      keypress  EXP8c_testRsp
# 120              1916.56069            False      keypress  EXP8c_testRsp
# 121              1916.56069            False      keypress  EXP8c_testRsp
# 122              1916.56069            False      keypress  EXP8c_testRsp
# 123              1916.56069            False      keypress  EXP8c_testRsp
# 124              1916.56069            False      keypress  EXP8c_testRsp
# 125              1916.56069            False      keypress  EXP8c_testRsp
# 126              1916.56069            False      keypress  EXP8c_testRsp
# 127              1916.56069            False      keypress  EXP8c_testRsp
# 128              1916.56069            False      keypress  EXP8c_testRsp
# 129              1916.56069            False      keypress  EXP8c_testRsp
# 130              1916.56069             True      keypress   cat_catchRsp
# 131              1916.56069            False      keypress  EXP8c_testRsp
# 132              1916.56069            False      keypress  EXP8c_testRsp
# 133              1916.56069            False      keypress  EXP8c_testRsp
# 134              1916.56069            False      keypress  EXP8c_testRsp
# 135              1916.56069            False      keypress  EXP8c_testRsp
# 136              1916.56069            False      keypress  EXP8c_testRsp
# 137              1916.56069            False      keypress  EXP8c_testRsp
# 138              1916.56069            False      keypress  EXP8c_testRsp
# 139              1916.56069            False      keypress  EXP8c_testRsp
# 140              1916.56069            False      keypress  EXP8c_testRsp
# 141              1916.56069            False      keypress  EXP8c_testRsp
# 142              1916.56069             True      keypress  bird_catchRsp
# 143              1916.56069            False      keypress  EXP8c_testRsp
# 144              1916.56069            False      keypress  EXP8c_testRsp
# 145              1916.56069            False      keypress  EXP8c_testRsp
# 146              1916.56069            False      keypress  EXP8c_testRsp
# 147              1916.56069            False      keypress  EXP8c_testRsp
# 148              1916.56069            False      keypress  EXP8c_testRsp
# 149              1916.56069            False      keypress  EXP8c_testRsp
#
#      response_rt  ...                session_id         session_start_time  \
# 100          348  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 101          656  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 102          415  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 103          406  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 104          296  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 105          373  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 106         2597  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 107          484  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 108          324  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 109          429  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 110          274  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 111          664  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 112         1204  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 113         1838  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 114          484  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 115          929  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 116          357  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 117          424  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 118         1432  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 119          569  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 120          381  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 121          407  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 122          496  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 123          514  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 124          498  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 125          405  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 126          395  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 127          926  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 128          400  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 129          357  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 130          800  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 131          542  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 132          333  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 133          222  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 134          330  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 135         1047  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 136          347  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 137          348  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 138          501  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 139          659  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 140          467  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 141          442  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 142          757  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 143          347  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 144          496  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 145         1316  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 146          343  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 147         1150  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 148          476  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
# 149          581  ...  635300ef7f3ee915ba688e53  2022-10-21 16:28:31-04:00
#
#                           stimuli_presented trial_duration trial_num  \
# 100    single_300ms_late_delay_2_tone_Lab_8           3851       101
# 101  single_300ms_ontime_delay_2_tone_Lab_2           3973       102
# 102   single_300ms_early_delay_2_tone_Lab_7           3730       103
# 103   single_300ms_early_delay_2_tone_Lab_6           3677       104
# 104    single_300ms_late_delay_2_tone_Lab_7           3750       105
# 105    single_300ms_late_delay_2_tone_Lab_3           3643       106
# 106                             cat_meowing           5514       107
# 107  single_300ms_ontime_delay_2_tone_Lab_1           3813       108
# 108   single_300ms_early_delay_2_tone_Lab_8           3697       109
# 109   single_300ms_early_delay_2_tone_Lab_2           3617       110
# 110  single_300ms_ontime_delay_2_tone_Lab_7           3671       111
# 111  single_300ms_ontime_delay_2_tone_Lab_8           3982       112
# 112  single_300ms_ontime_delay_2_tone_Lab_6           4576       113
# 113    single_300ms_late_delay_2_tone_Lab_4           5256       114
# 114    single_300ms_late_delay_2_tone_Lab_1           3837       115
# 115   single_300ms_early_delay_2_tone_Lab_5           4193       116
# 116    single_300ms_late_delay_2_tone_Lab_6           3841       117
# 117  single_300ms_ontime_delay_2_tone_Lab_5           3773       118
# 118                                songbird           4338       119
# 119   single_300ms_early_delay_2_tone_Lab_4           3797       120
# 120   single_300ms_early_delay_2_tone_Lab_1           3553       121
# 121   single_300ms_early_delay_2_tone_Lab_4           3632       122
# 122   single_300ms_early_delay_2_tone_Lab_7           3801       123
# 123   single_300ms_early_delay_2_tone_Lab_1           3687       124
# 124  single_300ms_ontime_delay_2_tone_Lab_6           3875       125
# 125    single_300ms_late_delay_2_tone_Lab_7           3908       126
# 126    single_300ms_late_delay_2_tone_Lab_3           3787       127
# 127  single_300ms_ontime_delay_2_tone_Lab_5           4288       128
# 128   single_300ms_early_delay_2_tone_Lab_2           3604       129
# 129    single_300ms_late_delay_2_tone_Lab_1           3726       130
# 130                             cat_meowing           3706       131
# 131   single_300ms_early_delay_2_tone_Lab_6           3808       132
# 132  single_300ms_ontime_delay_2_tone_Lab_1           3609       133
# 133  single_300ms_ontime_delay_2_tone_Lab_8           3645       134
# 134  single_300ms_ontime_delay_2_tone_Lab_7           3663       135
# 135    single_300ms_late_delay_2_tone_Lab_5           4469       136
# 136  single_300ms_ontime_delay_2_tone_Lab_4           3689       137
# 137   single_300ms_early_delay_2_tone_Lab_5           3598       138
# 138  single_300ms_ontime_delay_2_tone_Lab_3           3822       139
# 139    single_300ms_late_delay_2_tone_Lab_2           4037       140
# 140   single_300ms_early_delay_2_tone_Lab_3           3701       141
# 141    single_300ms_late_delay_2_tone_Lab_6           3935       142
# 142                                songbird           3745       143
# 143   single_300ms_early_delay_2_tone_Lab_8           3661       144
# 144    single_300ms_late_delay_2_tone_Lab_4           3927       145
# 145    single_300ms_late_delay_2_tone_Lab_8           4851       146
# 146  single_300ms_ontime_delay_2_tone_Lab_2           3626       147
# 147   single_300ms_early_delay_2_tone_Lab_3           4366       148
# 148   single_300ms_early_delay_2_tone_Lab_4           3738       149
# 149   single_300ms_early_delay_2_tone_Lab_1           3756       150
#
#                trial_template  sub_id    exp Correct Shorter
# 100  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 101  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 102  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 103  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 104  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 105  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 106              Catch_trials   cbea0  EXP8c       1       1
# 107  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 108  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 109  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 110  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 111  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 112  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 113  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 114  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 115  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 116  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 117  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 118              Catch_trials   cbea0  EXP8c       1       1
# 119  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 120  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 121  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 122  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 123  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 124  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 125  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 126  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 127  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 128  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 129  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 130              Catch_trials   cbea0  EXP8c       1       1
# 131  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 132  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 133  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 134  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 135  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 136  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 137  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 138  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 139  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 140  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 141  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 142              Catch_trials   cbea0  EXP8c       1       1
# 143  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 144  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 145  EXP8c_maintaskTrials_2_l   cbea0  EXP8c       0       1
# 146  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 147  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 148  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
# 149  EXP8c_maintaskTrials_2_s   cbea0  EXP8c       0       1
#
# [50 rows x 23 columns]

# %%
## Total participated subjects
len(df['sub_id'].unique())

# %%
df['exp'] = df['group_id'].apply(lambda x: x.split("_")[0])
print(len(df.groupby('group_id')['sub_id'].unique()['EXP8c_FJ']))
print(len(df.groupby('group_id')['sub_id'].unique()['EXP8c_JF']))

# %% [markdown]
# ## Set parameters
# - Accuracy threshold for the easiest trials of the main task
# - Extreme RT threshold
# - Catch trial accuracy

# %%
## Parameters
threshold = .55
catch_threshold = .7
RT_threshold = 10000
practice_threshold = 'pass'

# %% [markdown]
# ## Data cleaning
# ***Super important: df_clean is overwritten after each step of data cleaning***
#
# **Reject subjects**
# - Catch trial
# - Environmental noise & audio device (may not need to use them as criteria)
# - Fail the practice trial on the last 12 practice trial: pass people have done 24 trials, fail people have done 36 trials
#
# **Reject trials**
# - Task-relevant trials
# - Extreme RT

# %%
## How many subjects miss the catch trial 
catch_trials = ['Catch_trials'] ## for exp8abc

df_catch = df[(df['trial_template'].isin(catch_trials))].reset_index(drop = True) # reset index from 1
catch_acc = df_catch.groupby('sub_id')['response_correct'].sum()/df_catch.groupby('sub_id')['response_correct'].count()
fail_catch = catch_acc[catch_acc < catch_threshold].reset_index()
fail_catch

# %%
## remove subjects who failed the catch trial based on the threshold
df_clean = df[~df['sub_id'].isin(fail_catch['sub_id'])].reset_index(drop = True)

# %%
## How many subjects had a bad environmental noise and device
df_noise = df[(df['response_name'] == 'survey_noise')].reset_index(drop = True)
noise = df_noise.groupby('sub_id')['response_value'].sum()
too_noisy = noise[noise == '4'].reset_index()
too_noisy

# %%
## remove subjects who completed the task in noisy environment
df_clean = df_clean[~df_clean['sub_id'].isin(too_noisy['sub_id'])].reset_index(drop = True)

# %%
# may remove subjects who completed the task using low-quality audio device
df_device = df[(df['response_name'] == 'survey_headphone1')].reset_index()
len(df_device[['sub_id','response_value']] == 'Yes')

# %%
## remove subjects who failed the practice 
fail_prac = df[df['branch_failpass'] == 'fail']['sub_id'].unique()
len(fail_prac)

# %%
df_clean = df_clean[(~df_clean['sub_id'].isin(fail_prac))].reset_index()

# %%
## After cleaning how many subjects left
len(df_clean['sub_id'].unique())

# %% [markdown]
# ### Task relevant trials
# #### Select the trials to analyze
# - Pretest trails (n = 60): single tone 1 or 8
# - Practice trials (n = 24 or 36): 6 context tones + 1 ontime single tone 1 or 8 with correct/incorrect feedback
# - Main task (n = 576): 6 context tones + 1 single tone (early, ontime, late; 1 to 8 steps) without feedback

# %% [markdown]
# ### Select the pretest trials

# %%
df_clean['trial_template'].unique()

# %%
pre_trials = ['EXP8c_PretestTrials_s','EXP8c_PretestTrials_l','EXP8c_PretestTrials_s_rv','EXP8c_PretestTrials_l_rv']

df_pre = df_clean[(df_clean['trial_template'].isin(pre_trials))]

df_pre.groupby(['sub_id','stimuli_presented'])['Correct'].mean()
pre_acc = df_pre.groupby(['sub_id'])['Correct'].mean()
conds = df_pre['stimuli_presented'].unique()
print(conds) # check the conditions
df_pre.groupby('stimuli_presented')['Shorter'].mean()

# %%
df_pre['response_value']

# %%
for col in df_pre.columns:
    print(col)

# %% [markdown]
# ### Select the practice trials

# %%
df_prac = df_clean[(df_clean['task'] == "practiceTrials")].reset_index()
conds = df_prac['stimuli_presented'].unique()
print(conds) # check the conditions
df_prac.groupby('stimuli_presented')['Shorter'].mean()

# %%
df_clean_all = df_clean # create a new variable just in case

# %% [markdown]
# ## ??? under progress, need to write a code to save those *fail* who but pass on the last 12 trials???

# %%
# df_pra = df_pra[-12:-1]
# df_pra.groupby(['sub_id','stimuli_presented'])['Correct'].mean()
# pra_acc = df_pra.groupby(['sub_id'])['Correct'].mean()
# fail_pra = pra_acc[pra_acc != practice_threshold].reset_index()

# %% [markdown]
# ### Select the main trials

# %%
df_clean = df_clean[(df_clean['task'] == "maintaskTrials")].reset_index(drop = True)
conds = df_clean['stimuli_presented'].unique()
print(conds) # check the conditions

# %%
## Create new cols for onset and length
onset = []
length = []
df_clean = df_clean.set_index(pd.Index(np.arange(0,len(df_clean)))) # change the index for the for loop

for i in np.arange(0,len(df_clean)):
    stimuli_presented = df_clean['stimuli_presented'][i].split('_')
    onset.append(stimuli_presented[2])
    length.append(stimuli_presented[-1])
df_clean['Onset'] = onset
df_clean['Length'] = length

# %%
## Number of subjects, trials & conditions for each subjects
n_subj = len(df_clean['participant_id'].unique())
n_trial = len(df_clean)//n_subj # how many trials per subject
n_conds = len(df_clean['stimuli_presented'].unique())
print('Participant_number:', n_subj,'Trial number:', n_trial,'Condition number:', n_conds, sep='\n')

# %% [markdown]
# ### Accuracy

# %%
df_clean.groupby(['Onset'])['Correct'].mean()

# %%
accuracy_all = df_clean.groupby(['stimuli_presented','Onset'])['Correct'].mean()

# %%
## consider outliers based on the accuracy of the easiest trials 
outliers = Acc_easiest < threshold
outliers = outliers[outliers == True]
df_clean_nooutlier = df_clean[~df_clean['participant_id'].isin(outliers.index)]

# %%
## Visualization: bar plot
ACC_plot = pd.DataFrame({'Conditions': conds, 'accuracy': accuracy_all})
ax = ACC_plot.plot.bar(rot = 0)

# %% [markdown]
# ### Proportion short

# %%
df_clean.groupby(['Onset'])['Shorter'].mean()

# %%
pps = df_clean.groupby(['Onset'])['Shorter'].mean()
print('Proportion short')
print('Early',pps[0]) 
print('Ontime',pps[2])
print('Late',pps[1])

# %%
pps_all = df_clean.groupby(['stimuli_presented','Onset'])['Shorter'].mean()

# %%
## Visualization: bar plot
PPS_plot = pd.DataFrame({'Conditions': conds, 'PSS': pps_all})
ax = PPS_plot.plot.bar(rot = 0)
pps_all.plot(style='k--')

# %%
pps_all[8:16]

# %%
pps_all[0:8].plot(style = 'o-') # early
pps_all[8:16].plot(style ='ko-') # late
ax = pps_all[16:24].plot(style ='ro-') # ontime
ax.set_xticklabels([0,1,2,3,4,5,6,7,8])

# %% [markdown]
# ### Statistic tests

# %%
PPS = df_clean.groupby(['sub_id','Onset'])['Shorter'].mean()
PPS_early = PPS[::3]
PPS_ontime = PPS[1::3]
PPS_late = PPS[2::3]

# %%
print(stats.ttest_rel(PPS_early, PPS_late))
print(stats.ttest_rel(PPS_early, PPS_ontime))
print(stats.ttest_rel(PPS_late, PPS_ontime))

# %% [markdown]
# ## Save the onset and comparison length to the csv file for R analysis

# %%
## save df to csv
df_clean.to_csv(r'/Users/t.z.cheng/Google_Drive/Research/Delaydoesmatter/real_exp/exp4_20CR12/4c/results/EXP4c_clean_n59.csv', header=True)
