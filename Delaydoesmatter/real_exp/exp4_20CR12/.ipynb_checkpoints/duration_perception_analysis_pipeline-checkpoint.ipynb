# %% [markdown]
# ## Initialization
# - Import the package
# - Import the data

# %%
import csv
import numpy as np
import pandas as pd
from collections import defaultdict
import string
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from sklearn import linear_model
from sklearn import metrics # confusion matrix, MSE etc.

# %%
path_to_data = '/Users/t.z.cheng/Google_Drive/Research/Delaydoesmatter/real_exp/exp3_20CR11/results/20CR11_5f7d2e104bfca86e4f58ef9a-data.csv'

# %%
## Read the data
df = pd.read_csv(path_to_data)
# df_clean = df
## Take a look of the dataset
# df.head()
# df.tail()
# df.loc[558:663] # see specific rows of data

# %%
## Clean up task and subject ID (first five characters)
df['task'] = df['trial_template'].apply(lambda x: x.split("_")[0])
df['sub_id'] = df['participant_id'].apply(lambda x: x.split()[0][0:5])

# %%
## Add the accuracy and PPS column to the dataset: transform True and Shorter to 1, False and longer to 0
Correct = []
Shorter = []
for i in np.arange(0,len(df)):
    if df['response_correct'][i] == True:
        Correct.append(1)
    else: 
        Correct.append(0)
    if df['response_value'][i] == "Shorter":
        Shorter.append(1)
    else: 
        Shorter.append(0)
df['Correct'] = Correct
df['Shorter'] = Shorter

# %% [markdown]
# ## Set parameters
# - Accuracy threshold for the easiest trials of the main task
# - Extreme RT threshold
# - Catch trial accuracy

# %%
## Parameters
threshold = .55
catch_threshold = .8
RT_threshold = 10000

# %% [markdown]
# ## Data cleaning
# ***Super important: df_clean is overwritten after each step of data cleaning***
#
# **Reject subjects**
# - Practice accuracy in conditional branching block
# - Easiest comparison length (shortest and longest) in the main trial
# - Catch trial
# - Environmental noise & audio device (may not need to use them as criteria)
#
# **Reject trials**
# - Task-relevant trials
# - Extreme RT

# %% [markdown]
# ### Reject subjects

# %%
## How many subjects pass the practice > 0.75 on the easiest ontime trials 
df_clean = df[df['branch_failpass'] == 'pass'].reset_index(drop = True)
print('How many subjects passed the practice trials:', len(df_clean['sub_id'].unique())
      ,'out of',len(df['sub_id'].unique()))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'branch_failpass'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-6d12c97654f5> in <module>
#       1 ## How many subjects pass the practice > 0.75 on the easiest ontime trials
# ----> 2 df_clean = df[df['branch_failpass'] == 'pass'].reset_index(drop = True)
#       3 print('How many subjects passed the practice trials:', len(df_clean['sub_id'].unique())
#       4       ,'out of',len(df['sub_id'].unique()))
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'branch_failpass'

# %%
## How many subjects pass the main task easiest ontime trial > 0.55 
# main_task_easiest = ['single_300ms_delay_2_81','single_300ms_delay_2_86','single_300ms_delay_4_81','single_300ms_delay_4_86'] # EXP4
df_clean = df # EXP3
main_task_easiest = ['300ms_delay_2_81','300ms_delay_2_86','300ms_delay_4_81','300ms_delay_4_86'] # EXP3
df_main_task_easiest = df_clean[(df_clean['stimuli_presented'].isin(main_task_easiest)) & (df_clean['task'] == 'maintaskTrials')].reset_index(drop = True)
pass_subs = (df_main_task_easiest.groupby(['sub_id']).mean()['Correct'] > threshold).reset_index(name = 'main_task_easiest_pass')
df_clean = pd.merge(df_clean,pass_subs,on = 'sub_id')
df_clean = df_clean[df_clean['main_task_easiest_pass'] == True]
print('How many subjects passed the practice trials:', len(df_clean['sub_id'].unique())
      ,'out of',len(df['sub_id'].unique()))
# Out:
# How many subjects passed the practice trials: 34 out of 63

# %%
## How many subjects miss the catch trial 
catch_trials = ['Catch_beat','Catch_bag']
df_catch = df[(df['trial_template'].isin(catch_trials))].reset_index(drop = True) # reset index from 1
catch_acc = df_catch.groupby('sub_id')['response_correct'].sum()/df_catch.groupby('participant_id')['response_correct'].count()
catch_acc[catch_acc < catch_threshold]

# %%
## How many subjects had a bad environmental noise and device
df_noise = df[(df['response_name'] == 'survey_noise')].reset_index(drop = True)
noise = df_noise.groupby('sub_id')['response_value'].sum()
df_device = df[(df['response_name'] == 'survey_headphone')].reset_index(drop = True)
df_device[['sub_id','response_value']]
# Out:
#    sub_id                                     response_value
# 0   885d1  Built in Laptop/Desktop Speaker (Please use he...
# 1   34b38                                   Wired Headphones
# 2   2d961                                      Wired Earbuds
# 3   0528e                                   Wired Headphones
# 4   c186a                                   Wired Headphones
# ..    ...                                                ...
# 58  8ffb7                                      Wired Earbuds
# 59  57736                                   Wireless Earbuds
# 60  6b384                                Wireless Headphones
# 61  74872                                      Wired Earbuds
# 62  453ca  Built in Laptop/Desktop Speaker (Please use he...
#
# [63 rows x 2 columns]

# %% [markdown]
# ### Task relevant trials

# %%
## subj id
subID = df['sub_id'].unique()

# %%
## All condition
task = ["maintaskTrials"] 
# task = ["pretestTrials"] 
conds = ['single_300ms_delay_2_51','single_300ms_delay_2_52','single_300ms_delay_2_53','single_300ms_delay_2_54','single_300ms_delay_2_55','single_300ms_delay_2_56',
        'single_300ms_delay_2_81','single_300ms_delay_2_82','single_300ms_delay_2_83','single_300ms_delay_2_84','single_300ms_delay_2_85','single_300ms_delay_2_86',
        'single_300ms_delay_2_91','single_300ms_delay_2_92','single_300ms_delay_2_93','single_300ms_delay_2_94','single_300ms_delay_2_95','single_300ms_delay_2_96',
        'single_300ms_delay_4_51','single_300ms_delay_4_52','single_300ms_delay_4_53','single_300ms_delay_4_54','single_300ms_delay_4_55','single_300ms_delay_4_56',
        'single_300ms_delay_4_81','single_300ms_delay_4_82','single_300ms_delay_4_83','single_300ms_delay_4_84','single_300ms_delay_4_85','single_300ms_delay_4_86',
        'single_300ms_delay_4_91','single_300ms_delay_4_92','single_300ms_delay_4_93','single_300ms_delay_4_94','single_300ms_delay_4_95','single_300ms_delay_4_96']

# %%
## All condition
task = ["maintaskTrials"] 
# task = ["pretestTrials"] 
conds = ['300ms_delay_2_51','300ms_delay_2_52','300ms_delay_2_53','300ms_delay_2_54','300ms_delay_2_55','300ms_delay_2_56',
        '300ms_delay_2_81','300ms_delay_2_82','300ms_delay_2_83','300ms_delay_2_84','300ms_delay_2_85','300ms_delay_2_86',
        '300ms_delay_2_91','300ms_delay_2_92','300ms_delay_2_93','300ms_delay_2_94','300ms_delay_2_95','300ms_delay_2_96']

# %%
## Tasks & Conditions pretest
pretest_conds = ['short_tone_1','long_tone_6']
subID = df_clean['sub_id'].unique()

# %%
df_clean.iloc[55:100]
# Out:
#                       expt_id  group_id  network_error_repeat  \
# 294  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 295  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 296  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 297  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 298  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 299  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 300  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 301  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 302  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 303  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 304  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 305  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 306  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 307  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 308  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 309  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 310  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 311  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 312  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 313  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 314  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 315  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 316  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 317  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 318  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 319  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 320  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 321  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 322  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 323  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 324  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 325  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 326  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 327  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 328  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 329  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 330  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 331  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 332  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 333  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 334  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 335  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 336  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 337  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
# 338  5f7d2e104bfca86e4f58ef9a  Group_JF                     0
#
#                                         participant_id  \
# 294  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 295  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 296  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 297  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 298  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 299  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 300  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 301  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 302  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 303  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 304  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 305  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 306  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 307  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 308  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 309  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 310  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 311  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 312  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 313  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 314  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 315  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 316  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 317  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 318  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 319  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 320  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 321  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 322  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 323  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 324  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 325  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 326  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 327  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 328  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 329  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 330  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 331  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 332  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 333  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 334  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 335  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 336  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 337  34b38b84b781d28751b6846057394c59330d43f01ffed5...
# 338  34b38b84b781d28751b6846057394c59330d43f01ffed5...
#
#      participation_duration response_correct response_mode     response_name  \
# 294                    1666            False      keypress  testresponse_s_J
# 295                    1666            False      keypress  testresponse_l_F
# 296                    1666             True      keypress  testresponse_s_J
# 297                    1666            False      keypress  testresponse_l_F
# 298                    1666            False      keypress  testresponse_l_F
# 299                    1666             True      keypress  testresponse_l_F
# 300                    1666            False      keypress  testresponse_l_F
# 301                    1666             True      keypress  testresponse_s_J
# 302                    1666             True      keypress  testresponse_s_J
# 303                    1666             True      keypress  testresponse_s_J
# 304                    1666             True      keypress  testresponse_l_F
# 305                    1666             True      keypress  testresponse_l_F
# 306                    1666            False      keypress  testresponse_l_F
# 307                    1666            False      keypress  testresponse_s_J
# 308                    1666             True      keypress  testresponse_s_J
# 309                    1666            False      keypress  testresponse_l_F
# 310                    1666             True      keypress  testresponse_s_J
# 311                    1666             True      keypress  testresponse_s_J
# 312                    1666            False      keypress  testresponse_l_F
# 313                    1666            False      keypress  testresponse_l_F
# 314                    1666            False      keypress  testresponse_l_F
# 315                    1666            False      keypress  testresponse_l_F
# 316                    1666             True      keypress  testresponse_l_F
# 317                    1666             True      keypress  testresponse_s_J
# 318                    1666             True      keypress  testresponse_s_J
# 319                    1666            False      keypress  testresponse_s_J
# 320                    1666             True      keypress  testresponse_s_J
# 321                    1666             True      keypress  testresponse_l_F
# 322                    1666             True      keypress  testresponse_s_J
# 323                    1666             True      keypress  testresponse_s_J
# 324                    1666             True      keypress  testresponse_l_F
# 325                    1666             True      keypress  testresponse_s_J
# 326                    1666             True      keypress  testresponse_s_J
# 327                    1666            False      keypress  testresponse_l_F
# 328                    1666            False      keypress  testresponse_l_F
# 329                    1666            False      keypress  testresponse_l_F
# 330                    1666            False      keypress  testresponse_l_F
# 331                    1666             True      keypress  testresponse_s_J
# 332                    1666            False      keypress  testresponse_s_J
# 333                    1666            False      keypress  testresponse_s_J
# 334                    1666             True      keypress  testresponse_l_F
# 335                    1666            False      keypress  testresponse_l_F
# 336                    1666             True      keypress  testresponse_s_J
# 337                    1666             True      keypress  testresponse_s_J
# 338                    1666             True      keypress  testresponse_s_J
#
#      response_rt response_target  ...                session_id  \
# 294          331     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 295          595      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 296         1336     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 297          992      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 298         2144      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 299         1604      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 300         3055      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 301          543     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 302           55     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 303         1173     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 304           70      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 305          169      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 306          210      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 307          254     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 308          271     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 309          271      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 310          337     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 311         3782     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 312         1234      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 313         1637      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 314         1203      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 315         1147      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 316          320      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 317          728     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 318          480     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 319          352     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 320          767     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 321          410      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 322         1733     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 323         2339     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 324          227      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 325          884     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 326         2499     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 327          101      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 328           55      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 329          250      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 330          260      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 331          194     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 332          224     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 333          456     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 334          507      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 335          819      ['Longer']  ...  5fbc5590be36f3ba328bd883
# 336          579     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 337          362     ['Shorter']  ...  5fbc5590be36f3ba328bd883
# 338          670     ['Shorter']  ...  5fbc5590be36f3ba328bd883
#
#     stimuli_presented trial_duration trial_num                 trial_template  \
# 294  300ms_delay_2_92           4513        56  maintaskTrials_2_s_reversekey
# 295  300ms_delay_2_96           4890        57  maintaskTrials_2_l_reversekey
# 296  300ms_delay_2_91           5576        58  maintaskTrials_2_s_reversekey
# 297  300ms_delay_2_94           5260        59  maintaskTrials_2_l_reversekey
# 298  300ms_delay_2_95           6394        60  maintaskTrials_2_l_reversekey
# 299  300ms_delay_2_85           5783        61  maintaskTrials_2_l_reversekey
# 300  300ms_delay_2_55           7076        62  maintaskTrials_2_l_reversekey
# 301  300ms_delay_2_53           4613        63  maintaskTrials_2_s_reversekey
# 302  300ms_delay_2_81           4174        64  maintaskTrials_2_s_reversekey
# 303  300ms_delay_2_52           5138        65  maintaskTrials_2_s_reversekey
# 304  300ms_delay_2_54           4048        66  maintaskTrials_2_l_reversekey
# 305  300ms_delay_2_56           4184        67  maintaskTrials_2_l_reversekey
# 306  300ms_delay_2_86           4329        68  maintaskTrials_2_l_reversekey
# 307  300ms_delay_2_83           4328        69  maintaskTrials_2_s_reversekey
# 308  300ms_delay_2_51           4239        70  maintaskTrials_2_s_reversekey
# 309  300ms_delay_2_84           4434        71  maintaskTrials_2_l_reversekey
# 310  300ms_delay_2_82           4375        72  maintaskTrials_2_s_reversekey
# 311  300ms_delay_2_92           8006        73  maintaskTrials_2_s_reversekey
# 312  300ms_delay_2_54           5308        74  maintaskTrials_2_l_reversekey
# 313  300ms_delay_2_94           5864        75  maintaskTrials_2_l_reversekey
# 314  300ms_delay_2_96           5870        76  maintaskTrials_2_l_reversekey
# 315  300ms_delay_2_95           5420        77  maintaskTrials_2_l_reversekey
# 316  300ms_delay_2_86           4503        78  maintaskTrials_2_l_reversekey
# 317  300ms_delay_2_51           4781        79  maintaskTrials_2_s_reversekey
# 318  300ms_delay_2_52           4519        80  maintaskTrials_2_s_reversekey
# 319  300ms_delay_2_82           4500        81  maintaskTrials_2_s_reversekey
# 320  300ms_delay_2_83           4925        82  maintaskTrials_2_s_reversekey
# 321  300ms_delay_2_84           4564        83  maintaskTrials_2_l_reversekey
# 322  300ms_delay_2_81           5786        84  maintaskTrials_2_s_reversekey
# 323  300ms_delay_2_93           6576        85  maintaskTrials_2_s_reversekey
# 324  300ms_delay_2_85           4411        86  maintaskTrials_2_l_reversekey
# 325  300ms_delay_2_53           4819        87  maintaskTrials_2_s_reversekey
# 326  300ms_delay_2_91           6725        88  maintaskTrials_2_s_reversekey
# 327  300ms_delay_2_56           4122        89  maintaskTrials_2_l_reversekey
# 328  300ms_delay_2_55           4107        90  maintaskTrials_2_l_reversekey
# 329  300ms_delay_2_85           4405        91  maintaskTrials_2_l_reversekey
# 330  300ms_delay_2_96           4493        92  maintaskTrials_2_l_reversekey
# 331  300ms_delay_2_82           4295        93  maintaskTrials_2_s_reversekey
# 332  300ms_delay_2_83           4351        94  maintaskTrials_2_s_reversekey
# 333  300ms_delay_2_81           4583        95  maintaskTrials_2_s_reversekey
# 334  300ms_delay_2_54           4479        96  maintaskTrials_2_l_reversekey
# 335  300ms_delay_2_95           4973        97  maintaskTrials_2_l_reversekey
# 336  300ms_delay_2_52           4660        98  maintaskTrials_2_s_reversekey
# 337  300ms_delay_2_51           4404        99  maintaskTrials_2_s_reversekey
# 338  300ms_delay_2_93           4900       100  maintaskTrials_2_s_reversekey
#
#                task sub_id Correct Shorter  main_task_easiest_pass
# 294  maintaskTrials  34b38       0       0                    True
# 295  maintaskTrials  34b38       0       1                    True
# 296  maintaskTrials  34b38       1       1                    True
# 297  maintaskTrials  34b38       0       1                    True
# 298  maintaskTrials  34b38       0       1                    True
# 299  maintaskTrials  34b38       1       0                    True
# 300  maintaskTrials  34b38       0       1                    True
# 301  maintaskTrials  34b38       1       1                    True
# 302  maintaskTrials  34b38       1       1                    True
# 303  maintaskTrials  34b38       1       1                    True
# 304  maintaskTrials  34b38       1       0                    True
# 305  maintaskTrials  34b38       1       0                    True
# 306  maintaskTrials  34b38       0       1                    True
# 307  maintaskTrials  34b38       0       0                    True
# 308  maintaskTrials  34b38       1       1                    True
# 309  maintaskTrials  34b38       0       1                    True
# 310  maintaskTrials  34b38       1       1                    True
# 311  maintaskTrials  34b38       1       1                    True
# 312  maintaskTrials  34b38       0       1                    True
# 313  maintaskTrials  34b38       0       1                    True
# 314  maintaskTrials  34b38       0       1                    True
# 315  maintaskTrials  34b38       0       1                    True
# 316  maintaskTrials  34b38       1       0                    True
# 317  maintaskTrials  34b38       1       1                    True
# 318  maintaskTrials  34b38       1       1                    True
# 319  maintaskTrials  34b38       0       0                    True
# 320  maintaskTrials  34b38       1       1                    True
# 321  maintaskTrials  34b38       1       0                    True
# 322  maintaskTrials  34b38       1       1                    True
# 323  maintaskTrials  34b38       1       1                    True
# 324  maintaskTrials  34b38       1       0                    True
# 325  maintaskTrials  34b38       1       1                    True
# 326  maintaskTrials  34b38       1       1                    True
# 327  maintaskTrials  34b38       0       1                    True
# 328  maintaskTrials  34b38       0       1                    True
# 329  maintaskTrials  34b38       0       1                    True
# 330  maintaskTrials  34b38       0       1                    True
# 331  maintaskTrials  34b38       1       1                    True
# 332  maintaskTrials  34b38       0       0                    True
# 333  maintaskTrials  34b38       0       0                    True
# 334  maintaskTrials  34b38       1       0                    True
# 335  maintaskTrials  34b38       0       1                    True
# 336  maintaskTrials  34b38       1       1                    True
# 337  maintaskTrials  34b38       1       1                    True
# 338  maintaskTrials  34b38       1       1                    True
#
# [45 rows x 22 columns]

# %%
df_clean[(df_clean['stimuli_presented'].isin(conds)) & (df_clean['task'] == task)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-28f62c2a6b80> in <module>
# ----> 1 df_clean[(df_clean['stimuli_presented'].isin(conds)) & (df_clean['task'] == task)]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     524         rvalues = extract_array(other, extract_numpy=True)
#     525
# --> 526         res_values = comparison_op(lvalues, rvalues, op)
#     527
#     528         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     232         #  The ambiguous case is object-dtype.  See GH#27803
#     233         if len(lvalues) != len(rvalues):
# --> 234             raise ValueError("Lengths must match to compare")
#     235
#     236     if should_extension_dispatch(lvalues, rvalues):
#
# ValueError: Lengths must match to compare

# %%
## select the trials 
df_clean = df_clean[(df_clean['stimuli_presented'].isin(conds)) & (df_clean['task'] == task)].reset_index(drop = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-22a0e90d1e52> in <module>
#       1 ## select the trials
# ----> 2 df_clean = df_clean[(df_clean['stimuli_presented'].isin(conds)) & (df_clean['task'] == task)].reset_index(drop = True)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     524         rvalues = extract_array(other, extract_numpy=True)
#     525
# --> 526         res_values = comparison_op(lvalues, rvalues, op)
#     527
#     528         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     232         #  The ambiguous case is object-dtype.  See GH#27803
#     233         if len(lvalues) != len(rvalues):
# --> 234             raise ValueError("Lengths must match to compare")
#     235
#     236     if should_extension_dispatch(lvalues, rvalues):
#
# ValueError: Lengths must match to compare

# %%
## Long format for each condition
# B/T: presenting order & response key
# W/I: Onset time, comparison length, delay length
df_clean['onset'] = df_clean['stimuli_presented'].apply(lambda x: x.split("_")[-1][0])
df_clean['delay'] = df_clean['stimuli_presented'].apply(lambda x: x.split("_")[-2])
df_clean['comparison'] = df_clean['stimuli_presented'].apply(lambda x: x.split("_")[-1][1])
df_clean['order'] = df_clean['group_id'].apply(lambda x: x.split("_")[-1])
df_clean['key'] = df_clean['group_id'].apply(lambda x: x.split("_")[-2])

# %% [markdown]
# ### Extreme reaction time

# %%
df_clean_longRT = df_clean[df_clean['response_rt'] > RT_threshold]

# %% [markdown]
# ## Analyze noise and overall accuracy/catch accuracy

# %%
noise = noise.astype(int) # turn str to int to do correlaton
acc = df_clean.groupby('sub_id')['response_correct'].sum()/\
df_clean.groupby('sub_id')['response_correct'].count()

# %%
corr = np.corrcoef(noise,acc)[0,1]
print(corr, '\n')
corr = np.corrcoef(noise,catch_acc)[0,1]
print(corr, '\n')

# %%
# plot the data...
plt.scatter(acc,noise,color='r')
plt.xlabel('Accuracy')
plt.ylabel('Noise')
plt.show()

# %%
# plot the data...
plt.scatter(catch_acc,noise,color='r')
plt.hist(catch_acc,noise)
plt.xlabel('Accuracy')
plt.ylabel('Noise')
plt.show()

# %% [markdown]
# ## Save the onset and comparison length to the csv file for R analysis

# %%
## save df to csv
df_clean.to_csv(r'/Users/t.z.cheng/Google_Drive/Research/Delaydoesmatter/real_exp/exp4_20CR12/results_shortlongdelay_2021/v2_20CR12_clean_n67_cleaned.csv', header=True)

# %% [markdown]
# ## Analyze trials of the main task

# %%
## Number of subjects, trials & conditions for each subjects
n_subj = len(df_clean['sub_id'].unique())
n_trial = len(df_clean)//15
n_conds = len(df_clean['stimuli_presented'].unique())
print('Participant_number:', n_subj,'Trial number:', n_trial,'Condition number:', n_conds, sep='\n')

# %%
## Group_by
overall_acc = df_clean.groupby(['sub_id']).mean()['Correct'].reset_index(drop = True)
overall_pps = df_clean.groupby(['sub_id']).mean()['Shorter'].reset_index(drop = True)
all_conds_acc = df_clean.groupby(['sub_id','onset','delay','comparison','order','key']).mean()['Correct'].reset_index(drop = True)
all_conds_pps = df_clean.groupby(['sub_id','onset','delay','comparison','order','key']).mean()['Shorter'].reset_index(drop = True)

# %% [markdown]
# ## Visualization

# %%
## Visualize acc across delay and onset
df_clean.groupby(['delay','onset']).mean()['Correct'].plot.bar(rot = 0)

# %%
## Visualize proportion short across delay and onset 
df_clean.groupby(['delay','onset']).mean()['Shorter'].plot.bar(rot = 0)

# %%
## Early, ontime, late long delay
early = [conds.index('single_300ms_delay_4_51'),conds.index('single_300ms_delay_4_52'),conds.index('single_300ms_delay_4_53'),conds.index('single_300ms_delay_4_54'),conds.index('single_300ms_delay_4_55'),conds.index('single_300ms_delay_4_56')]
ontime = [conds.index('single_300ms_delay_4_81'),conds.index('single_300ms_delay_4_82'),conds.index('single_300ms_delay_4_83'),conds.index('single_300ms_delay_4_84'),conds.index('single_300ms_delay_4_85'),conds.index('single_300ms_delay_4_86')]
late = [conds.index('single_300ms_delay_4_91'),conds.index('single_300ms_delay_4_92'),conds.index('single_300ms_delay_4_93'),conds.index('single_300ms_delay_4_94'),conds.index('single_300ms_delay_4_95'),conds.index('single_300ms_delay_4_96')]
Acc_early = Acc_final_sample.iloc[:, early].mean(axis = 1)
Acc_ontime = Acc_final_sample.iloc[:, ontime].mean(axis = 1)
Acc_late = Acc_final_sample.iloc[:, late].mean(axis = 1)
print("Accuracy")
print("Early:", np.mean(Acc_early))
print("Ontime:", np.mean(Acc_ontime))
print("Late:",np.mean(Acc_late))

# %%
## Visualization: bar plot
ACC_plot = pd.DataFrame({'Conditions': conds, 'acc': np.mean(Acc_final_sample, axis = 0)})
ax = ACC_plot.plot.bar(rot = 0)

# %% [markdown]
# ### Proportion short

# %%
resp_short = []
resp_short = [True if d == 'Shorter' else False for d in df_clean['response_value']]

# %%
df_clean['resp_short'] = resp_short

# %%
PPS = []
PPS_cond = []
for sub in subID:
    tmpdf = df_clean[df_clean['participant_id'] == sub]
    for cond in conds:
        tmpPPS = np.mean(tmpdf[tmpdf['stimuli_presented'] == cond]['resp_short'])
        PPS_cond.append(tmpPPS)
    PPS.append(PPS_cond)
    PPS_cond = []

# %%
df_PPS = pd.DataFrame(data = PPS, index = subID, columns = conds)

# %%
PPS_final_sample = df_PPS[Acc_easiest >= threshold]
PPS_final_sample.head()
PPS_final_sample.describe()

# %%
## Early, ontime, late short
early = [conds.index('single_300ms_delay_2_51'),conds.index('single_300ms_delay_2_52'),conds.index('single_300ms_delay_2_53'),conds.index('single_300ms_delay_2_54'),conds.index('single_300ms_delay_2_55'),conds.index('single_300ms_delay_2_56')]
ontime = [conds.index('single_300ms_delay_2_81'),conds.index('single_300ms_delay_2_82'),conds.index('single_300ms_delay_2_83'),conds.index('single_300ms_delay_2_84'),conds.index('single_300ms_delay_2_85'),conds.index('single_300ms_delay_2_86')]
late = [conds.index('single_300ms_delay_2_91'),conds.index('single_300ms_delay_2_92'),conds.index('single_300ms_delay_2_93'),conds.index('single_300ms_delay_2_94'),conds.index('single_300ms_delay_2_95'),conds.index('single_300ms_delay_2_96')]
PPS_early = PPS_final_sample.iloc[:, early].mean(axis = 1)
PPS_ontime = PPS_final_sample.iloc[:, ontime].mean(axis = 1)
PPS_late = PPS_final_sample.iloc[:, late].mean(axis = 1)
print("Proportion short")
print("Early:", np.mean(PPS_early))
print("Ontime:", np.mean(PPS_ontime))
print("Late:",np.mean(PPS_late))

# %%
## Early, ontime, late long
early = [conds.index('single_300ms_delay_4_51'),conds.index('single_300ms_delay_4_52'),conds.index('single_300ms_delay_4_53'),conds.index('single_300ms_delay_4_54'),conds.index('single_300ms_delay_4_55'),conds.index('single_300ms_delay_4_56')]
ontime = [conds.index('single_300ms_delay_4_81'),conds.index('single_300ms_delay_4_82'),conds.index('single_300ms_delay_4_83'),conds.index('single_300ms_delay_4_84'),conds.index('single_300ms_delay_4_85'),conds.index('single_300ms_delay_4_86')]
late = [conds.index('single_300ms_delay_4_91'),conds.index('single_300ms_delay_4_92'),conds.index('single_300ms_delay_4_93'),conds.index('single_300ms_delay_4_94'),conds.index('single_300ms_delay_4_95'),conds.index('single_300ms_delay_4_96')]
PPS_early = PPS_final_sample.iloc[:, early].mean(axis = 1)
PPS_ontime = PPS_final_sample.iloc[:, ontime].mean(axis = 1)
PPS_late = PPS_final_sample.iloc[:, late].mean(axis = 1)
print("Proportion short")
print("Early:", np.mean(PPS_early))
print("Ontime:", np.mean(PPS_ontime))
print("Late:",np.mean(PPS_late))

# %%
## Visualization: bar plot
PSS_plot = pd.DataFrame({'Conditions': conds, 'PSS': np.mean(PPS_final_sample, axis = 0)})
ax = PSS_plot.plot.bar(rot = 0)

# %% [markdown]
# ### Statistic tests

# %%
print(stats.ttest_rel(PPS_early, PPS_late))
print(stats.ttest_rel(PPS_early, PPS_ontime))
print(stats.ttest_rel(PPS_late, PPS_ontime))
